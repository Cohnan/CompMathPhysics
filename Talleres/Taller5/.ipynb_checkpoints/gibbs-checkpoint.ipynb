# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Taller 5
# Métodos Computacioinales 2015-19
#
# Sebastian Puerto, 201318518

# %% [markdown]
# Se quiere hallar una aproximación de la constante de Wilbraham–Gibbs. Ésta es una constante que aparece en las discontinuidades de las series de Fourier de ; ésta es el error porcentual de la diferencia de los valores límites de la función original al lado de la discontinuidad, y el valor dado por la serie de Fourier allí.
#
# Lo que haremos entonces es hacer aproximaciones con sumas parciales de la serie de Fourier de una función con discontinuidades, de manera que la constante de Gibbs sea considerada el límite de un valor obtenido a partir de la diferencia entre los valores máximos obtenidos cerca a las discontinuidades.

# %% [markdown]
# La función a usar es una onda cuadrada de altura $\frac{\pi}{4}$, y periodo $2\pi$, cuya serie de Fourier está dada por: $$\sum_{i=0}^\infty \frac{1}{2i+1} sin[(2i+1)x] = sin(x) + \frac{1}{3}sin(3x) + \frac{1}{5}sin(5x) + \dots$$

# %%
def cuadrada(x, L = np.pi):
    xe = x % (2*L)
    if xe < L:
        return np.pi/4
    return -np.pi/4

def cuadrada_parcial(x, n, L = np.pi):
    suma = 0
    
    for i in range(n):
        suma += (1) * 1./(2*i + 1) * np.sin((2*i + 1)*np.pi*x/L)
    
    return suma

# %% [markdown]
# Algunas gráficas de estas funciones:

# %%
L = np.pi

figc = plt.figure("Cuadrada", figsize = (9, 9))

x = np.linspace(-L/10, 2*L + L/10, 300)
yc = np.vectorize(cuadrada)(x, L)

plt.axis([0 - L/10., 2*L + L/10., -1, 1])
plt.plot(x, yc)

for i in range(1, 1 + 3):
    y = array([cuadrada_parcial(el, 1 + 3 * i, L) for el in x])
    plt.plot(x, y)

plt.show()

# %%
from scipy.optimize import basinhopping as baho
from scipy.optimize import curve_fit

# %% [markdown]
# Para hallar un valor aproximado de la constante de Gibbs, se hace el cálculo de diferencia entre valores en los extremos globales de la función, se le resta la diferencia entre los límites a ambos lados de la función junto a las discontinuidades, y se divi

# %%
saltos = []
numero = 40
empieza = 10
delta = 1

for i in range(empieza, empieza + numero*delta, delta):#range(empieza, 1 + empieza + numero):
    cp = lambda x: cuadrada_parcial(x, i)
    saltos.append(abs(baho(cp, L, T = L/5., stepsize = 1).fun * 2))

# %% [markdown]
# Gráfica de aproximaciones de la constante de Gibbs según el número de términos utilizados de la serie de Fourier:

# %%
ns = array([i for i in range(empieza, empieza + numero*delta, delta)])

cG = [(el - np.pi/2) / (np.pi)  for el in saltos]

figG = plt.figure("Gibs", figsize = (9, 5))

plt.title("Constante de Gibbs\n")
plt.grid( )
plt.ylim([0.0894, 0.09])
plt.xlabel("N")
plt.ylabel("Constante de Gibbs estimada")
plt.scatter(ns, cG)

print "Ultimo valor:", (saltos[-1] - np.pi/2) / (np.pi)   #Ultimo valor, que dado el comportamiento, es el mas cercano
# Out:
# Ultimo valor: 0.0895072269322

# %% [markdown]
# La gráfica decrece y parece acercarse a una asíntota horizontal cerca al valor $0.0895018423647$, indicando que la constante de Wilbraham Gibbs es aproximádamente, y menor a, $0.0895018423647$
